# %%
import numpy as np
import os
import datetime
from astropy.io import fits
import xspec
from xspec import *
from xspec import AllModels, AllData, Fit, Plot

AllData.clear()
AllModels.clear()

basepathmod = '/mnt/c/Users/User/Downloads/chspec-main/'
AllModels.lmod('chspec', dirPath=basepathmod)
print("Model package chisoth successfully loaded.")
# Out:
# Model package chisoth successfully loaded.

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
import glob


# Initialize lists to store the results
temperatur = []

norm = []
r_chi=[]

Fe_abun=[]
Ni_abun=[]
S_err=[]
Ca_abun=[]
Ar_abun=[]
S_abun=[]
Fe_err=[]
Ni_err=[]
Ar_err=[]
Ca_err=[]
time=[]
timeFe=[]
timeNi=[]
timeCa=[]
timeAr=[]
timeS=[]
const=[]
# Load the data file
#file = "spectra/spectra1/Al1_spec"

Plot.device = '/xw'    
Plot.xAxis = 'keV'

#Plot('ld')

# %%
files1="paper/ch2_xsm_20240912_2_spectrum_corrected.pha"
for i in range(1,61):

    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(f"{files1}{{{i}}}")
    #resp = spec.response
    #resp.arf = None  # or use "" (empty string)
    #resp.arf = "paper/ch2_xsm_20240912_2.arf"


    spec.ignore("**-2.2 12.0-**")
    xspec.AllModels.systematic = 0.00
    xspec.AllModels.clear()
    time.append(i*30)
    model1 = xspec.Model("chisoth")
    #model1(1).values=[7]
    xspec.Fit.perform()
    
    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    #model1(14).frozen=False #Si abundance
    
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abun.append(model1(26).values[0])
       Fe_err.append(model1(26).sigma)
       timeFe.append(i*30)
    if model1(20).sigma<=1:   
       Ca_abun.append(model1(20).values[0])
       Ca_err.append(model1(20).sigma)
       timeCa.append(i*30)
    if model1(18).sigma<=1:
       Ar_abun.append(model1(18).values[0]) 
       Ar_err.append(model1(18).sigma)
       timeAr.append(i*30)
    if model1(28).sigma<=1:
       Ni_abun.append(model1(28).values[0])
       Ni_err.append(model1(28).sigma)
       timeNi.append(i*30)
    if model1(16).sigma<=1:
       S_abun.append(model1(16).values[0])
       S_err.append(model1(16).sigma)
       timeS.append(i*30)
    #Si_abun.append(model1(14).values[0])
    temp=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatur.append(temp/1000000)
    norm.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_chi.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
# Initialize lists to store the results
temperatu = []

nor = []
r_ch=[]

Fe_abu=[]
Ni_abu=[]
S_er=[]
Ca_abu=[]
Ar_abu=[]
S_abu=[]
Fe_er=[]
Ni_er=[]
Ar_er=[]
Ca_er=[]
tim=[]
timeF=[]
timeN=[]
timeC=[]
timeA=[]
times=[]

# Load the data file
#file = "spectra/spectra1/Al1_spec"


#Plot('ld')

# %%
files1="paper/ch2_xsm_20240912_2_binwise_corrected.pha"
for i in range(1,61):

    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(f"{files1}{{{i}}}")
    
    
    spec.ignore("**-2.2 12.0-**")
    xspec.AllModels.systematic = 0.00
    xspec.AllModels.clear()
    tim.append(i*30)
    model1 = xspec.Model("chisoth")
    #model1(1).values=[7]
    xspec.Fit.perform()
    
    
    
    #model1(14).frozen=False #Si abundance
    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abu.append(model1(26).values[0])
       Fe_er.append(model1(26).sigma)
       timeF.append(i*30)
    if model1(20).sigma<=1:   
       Ca_abu.append(model1(20).values[0])
       Ca_er.append(model1(20).sigma)
       timeC.append(i*30)
    if model1(18).sigma<=1:
       Ar_abu.append(model1(18).values[0]) 
       Ar_er.append(model1(18).sigma)
       timeA.append(i*30)
    if model1(28).sigma<=1:
       Ni_abu.append(model1(28).values[0])
       Ni_er.append(model1(28).sigma)
       timeN.append(i*30)
    if model1(16).sigma<=1:
       S_abu.append(model1(16).values[0])
       S_er.append(model1(16).sigma)
       times.append(i*30)
    #Si_abun.append(model1(14).values[0])
    tempe=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatu.append(tempe/1000000)
    nor.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_ch.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
# Initialize lists to store the results
temperatu1 = []

nor1 = []
r_ch1=[]

Fe_abu1=[]
Ni_abu1=[]
S_er1=[]
Ca_abu1=[]
Ar_abu1=[]
S_abu1=[]
Fe_er1=[]
Ni_er1=[]
Ar_er1=[]
Ca_er1=[]
tim1=[]
timeF1=[]
timeN1=[]
timeC1=[]
timeA1=[]
times1=[]

# Load the data file
#file = "spectra/spectra1/Al1_spec"


#Plot('ld')

# %%
files2 = sorted(glob.glob("paper/al1_20240912/" + "*.pi"))


for i, file in enumerate(files2):
    

    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(file)
    
    
    spec.ignore("**-2.2 12.0-**")
    xspec.AllModels.systematic = 0.04
    xspec.AllModels.clear()
    tim1.append(i*30)
    model1 = xspec.Model("chisoth")
    model1(1).values=[7]
    xspec.Fit.perform()
    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abu1.append(model1(26).values[0])
       Fe_er1.append(model1(26).sigma)
       timeF1.append(i*30)
    if model1(20).sigma<=1:   
       Ca_abu1.append(model1(20).values[0])
       Ca_er1.append(model1(20).sigma)
       timeC1.append(i*30)
    if model1(18).sigma<=1:
       Ar_abu1.append(model1(18).values[0]) 
       Ar_er1.append(model1(18).sigma)
       timeA1.append(i*30)
    if model1(28).sigma<=1:
       Ni_abu1.append(model1(28).values[0])
       Ni_er1.append(model1(28).sigma)
       timeN1.append(i*30)
    if model1(16).sigma<=1:
       S_abu1.append(model1(16).values[0])
       S_er1.append(model1(16).sigma)
       times1.append(i*30)
    #Si_abun.append(model1(14).values[0])
    tempe=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatu1.append(tempe/1000000)
    nor1.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_ch1.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
#file=fits.open("/mnt/c/Users/User/Downloads/work/AL1_SOLEXS_20240912_SDD2_L1.lc")
file=fits.open("/mnt/c/Users/User/Downloads/work/ch2_xsm_20240912_v1/xsm/data/2024/09/12/calibrated/ch2_xsm_20240912_v1_level2.lc")
print(file.info())
#extracting data
data=file[1].data

print(file[1].header)
time2 = data['TIME']
counts1 = data['RATE']
#plotting
plt.figure(figsize=(10, 6))
plt.xscale('log')
#plt.axvspan(242867729.83908,242870399.603349) 
plt.plot(time2, counts1,'o',label='XSM light curve')
# Out:
# Filename: /mnt/c/Users/User/Downloads/work/ch2_xsm_20240912_v1/xsm/data/2024/09/12/calibrated/ch2_xsm_20240912_v1_level2.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      15   ()
#   1  RATE          1 BinTableHDU     64   80611R x 4C   [D, E, E, E]
# None
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / 8-bit bytes                                    NAXIS   =                    2 / 2-dimensional binary table                     NAXIS1  =                   20 / width of table in bytes                        NAXIS2  =                80611 / number of rows in table                        PCOUNT  =                    0 / size of special data area                      GCOUNT  =                    1 / one data group (required keyword)              TFIELDS =                    4 / number of fields in each row                   TTYPE1  = 'TIME    '           / label for field   1                            TFORM1  = 'D       '           / data format of field: 8-byte DOUBLE            TTYPE2  = 'RATE    '           / label for field   2                            TFORM2  = 'E       '           / data format of field: 4-byte REAL              TTYPE3  = 'ERROR   '           / label for field   3                            TFORM3  = 'E       '           / data format of field: 4-byte REAL              TTYPE4  = 'FRACEXP '           / label for field   4                            TFORM4  = 'E       '           / data format of field: 4-byte REAL              TUNIT1  = 's       '           / physical unit of field                         TUNIT2  = 'count/s '           / physical unit of field                         TUNIT3  = 'counts/s'           / physical unit of field                         EXTNAME = 'RATE    '           / name of this binary table extension            DATE-OBS= '2024-09-12 00:00:00.604555000' / Date observation start              DATE-END= '2024-09-12 23:59:59.354779000' / Date observation end                TSTART  =     242870400.603555 / Start Time                                     TSTOP   =     242956800.353779 / Stop Time                                      TIMESYS = 'UTC     '           / Time system                                    MJDREF  =               57754. / MJD reference                                  MISSION = 'CHANDRAYAAN-2'      / Name of mission/satellite                      TELESCOP= 'CH-2_ORBITER'       / Name of mission/satellite                      INSTRUME= 'CH2_XSM '           / Name of Instrument/detector                    ORIGIN  = 'PRLPOC  '           / Source of FITS file                            CREATOR = 'xsmgenlc '          / Creator of file                                HDUCLASS= 'OGIP    '           / OGIP Standard                                  HDUCLAS1= 'LIGHTCURVE'                                                          HDUCLAS2= 'TOTAL   '           / total lc                                       TIMESYS = 'UTC      '          / Time measured from                             TIMEREF = 'LOCAL   '           / reference time                                 TIMEUNIT= 's       '           / unit for time keywords                         TELAPSE =     86399.7502239943 / elapsed time                                   TIMEDEL =                   1. / delta time                                     CHSTART =                    0 / PHA channel start                              CHSTOP  =                  960 / PHA channel stop                               XSMDASVE= '1.30    '           / Version of XSMDAS that created this file       CALDBVER= '20210628'           / Version of XSM CALDB used                      EXTVER  =                    1 / auto assigned by template parser               FILENAME= 'ch2_xsm_20240912_v1_level2.lc'                                       DATE    = '2024-09-18T20:42:14'                                                 HISTORY ************** XSMGENLC **************                                  HISTORY l1file = ch2_xsm_20240912_v1_level1.fits                                HISTORY lcfile = ch2_xsm_20240912_v1_level2.lc                                  HISTORY lctype = standard                                                        ...

# %%
Time=[]
Counts=[]
time3=time2[0:1800]
Time.append(np.array(time3))
Counts.append(counts1[0:1800])

# %%
cnts = np.concatenate(Counts)
tme=np.concatenate(Time)

# %%
tme=tme-tme[0]

# %%
import datetime


def timestamp2datetime(timestamp_arr):
    datetime_arr = []
    for ta in timestamp_arr:
        datetime_arr.append(datetime.datetime.fromtimestamp(ta))
    return datetime_arr
converted_datetimes = timestamp2datetime(tme)

# %%
plt.plot(tme,cnts)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits




fig,ax=plt.subplots(8,1,figsize=(9,12),gridspec_kw={'height_ratios':(4,2,2,2,2,2,2,1)},sharex=True)



  
ax[0].plot(time,temperatur,'+',linestyle='-',color='blue',label='XSM Spectrum Corrected')
ax[0].plot(tim,temperatu,'+',linestyle='-',color='black',label='XSM binwise corrected')
ax[0].plot(tim1,temperatu1,'+',linestyle='-',color='cyan',label='SOLEXS')
ax[0].set_ylabel('Temperature(MK)')
ax[0].tick_params(axis='y')
ax[0].set_title("Energy range 2.2 to 10keV")
ax[0].legend(bbox_to_anchor=(1.15, 1), loc='upper left')
axs2=ax[0].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[1].plot(time,norm,'+',linestyle='-',color='blue')
ax[1].plot(tim,nor,'+',linestyle='-',color='black')
ax[1].plot(tim1,nor1,'+',linestyle='-',color='cyan')
ax[1].set_ylabel('Emission measure (1e46)')
ax[1].tick_params(axis='y',labelcolor='r')

axs2=ax[1].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')



ax[2].errorbar(timeFe,Fe_abun,yerr=Fe_err,fmt='+',linestyle='-',color='blue')
ax[2].errorbar(timeF,Fe_abu,yerr=Fe_er,fmt='+',linestyle='-',color='black')
ax[2].errorbar(timeF1,Fe_abu1,yerr=Fe_er1,fmt='+',linestyle='-',color='cyan')
ax[2].axhline(y=8.10,linestyle='--',color='black',label='Fe')
ax[2].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[2].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')


ax[3].errorbar(timeNi,Ni_abun,yerr=Ni_err,fmt='+',linestyle='-',color='blue')
ax[3].errorbar(timeN,Ni_abu,yerr=Ni_er,fmt='+',linestyle='-',color='black')
ax[3].errorbar(timeN1,Ni_abu1,yerr=Ni_er1,fmt='+',linestyle='-',color='cyan')
ax[3].axhline(y=6.84,linestyle='-.',color='blue',label='Ni')
#ax[1].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[1].set_ylim(5,10)
ax[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[3].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')




ax[4].errorbar(timeCa,Ca_abun,yerr=Ca_err,fmt='+',linestyle='-',color='blue')
ax[4].errorbar(timeC,Ca_abu,yerr=Ca_er,fmt='+',linestyle='-',color='black')
ax[4].errorbar(timeC1,Ca_abu1,yerr=Ca_er1,fmt='+',linestyle='-',color='cyan')
ax[4].axhline(y=6.93,linestyle='--',color='black',label='Ca')
ax[4].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[4].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')



ax[5].errorbar(timeAr,Ar_abun,yerr=Ar_err,fmt='+',linestyle='-',color='blue')
ax[5].errorbar(timeA,Ar_abu,yerr=Ar_er,fmt='+',linestyle='-',color='black')
ax[5].errorbar(timeA1,Ar_abu1,yerr=Ar_er1,fmt='+',linestyle='-',color='cyan')
ax[5].axhline(y=6.58,linestyle='-',color='blue', label='Ar')
ax[5].set_ylabel('Abundance')
#ax[2].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[2].set_ylim(5.5,8)
ax[5].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[5].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[6].errorbar(time,S_abun,yerr=S_err,fmt='+',linestyle='-',color='blue')
ax[6].errorbar(times,S_abu,yerr=S_er,fmt='+',linestyle='-',color='black')
ax[6].errorbar(times1,S_abu1,yerr=S_er1,fmt='+',linestyle='-',color='cyan')
ax[6].axhline(y=7.27,linestyle=':',color='blue',label='S')
#ax[3].axvline(400,linestyle='--',color='black',label='M6 flare peak')
ax[6].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[6].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[7].plot(time,r_chi,'+',color='blue')
ax[7].plot(tim,r_ch,'+',color='black')
ax[7].plot(tim1,r_ch1,'+',color='cyan')
ax[7].set_ylabel('reduced chi-square')
ax[7].set_xlabel('Time(sec)')
ax[7].tick_params(axis='y',labelcolor='red')


 
plt.savefig("paper/xsm_solexs_2_10.png",dpi=600,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1774/1961673163.py:48: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1774/1961673163.py:62: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1774/1961673163.py:76: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1774/1961673163.py:92: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1774/1961673163.py:104: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits




fig,ax=plt.subplots(8,1,figsize=(9,12),gridspec_kw={'height_ratios':(4,2,2,2,2,2,2,1)},sharex=True)



  
ax[0].plot(time,temperatur,'+',linestyle='-',color='blue',label='XSM Spectrum Corrected')
ax[0].plot(tim,temperatu,'+',linestyle='-',color='black',label='XSM binwise corrected')
ax[0].plot(tim1,temperatu1,'+',linestyle='-',color='cyan',label='SOLEXS')
ax[0].set_ylabel('Temperature(MK)')
ax[0].tick_params(axis='y')
ax[0].set_title("Energy range 2.2 to 10keV")
ax[0].legend(bbox_to_anchor=(1.15, 1), loc='upper left')
axs2=ax[0].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[1].plot(time,norm,'+',linestyle='-',color='blue')
ax[1].plot(tim,nor,'+',linestyle='-',color='black')
ax[1].plot(tim1,nor1,'+',linestyle='-',color='cyan')
ax[1].set_ylabel('Emission measure (1e46)')
ax[1].tick_params(axis='y',labelcolor='r')

axs2=ax[1].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')



ax[2].errorbar(timeFe,Fe_abun,yerr=Fe_err,fmt='+',linestyle='-',color='blue')
ax[2].errorbar(timeF,Fe_abu,yerr=Fe_er,fmt='+',linestyle='-',color='black')
ax[2].errorbar(timeF1,Fe_abu1,yerr=Fe_er1,fmt='+',linestyle='-',color='cyan')
ax[2].axhline(y=8.10,linestyle='--',color='black',label='Fe')
ax[2].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[2].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')


ax[3].errorbar(timeNi,Ni_abun,yerr=Ni_err,fmt='+',linestyle='-',color='blue')
ax[3].errorbar(timeN,Ni_abu,yerr=Ni_er,fmt='+',linestyle='-',color='black')
ax[3].errorbar(timeN1,Ni_abu1,yerr=Ni_er1,fmt='+',linestyle='-',color='cyan')
ax[3].axhline(y=6.84,linestyle='-.',color='blue',label='Ni')
#ax[1].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[1].set_ylim(5,10)
ax[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[3].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')




ax[4].errorbar(timeCa,Ca_abun,yerr=Ca_err,fmt='+',linestyle='-',color='blue')
ax[4].errorbar(timeC,Ca_abu,yerr=Ca_er,fmt='+',linestyle='-',color='black')
ax[4].errorbar(timeC1,Ca_abu1,yerr=Ca_er1,fmt='+',linestyle='-',color='cyan')
ax[4].axhline(y=6.93,linestyle='--',color='black',label='Ca')
ax[4].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[4].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')



ax[5].errorbar(timeAr,Ar_abun,yerr=Ar_err,fmt='+',linestyle='-',color='blue')
ax[5].errorbar(timeA,Ar_abu,yerr=Ar_er,fmt='+',linestyle='-',color='black')
ax[5].errorbar(timeA1,Ar_abu1,yerr=Ar_er1,fmt='+',linestyle='-',color='cyan')
ax[5].axhline(y=6.58,linestyle='-',color='blue', label='Ar')
ax[5].set_ylabel('Abundance')
#ax[2].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[2].set_ylim(5.5,8)
ax[5].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[5].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[6].errorbar(time,S_abun,yerr=S_err,fmt='+',linestyle='-',color='blue')
ax[6].errorbar(times,S_abu,yerr=S_er,fmt='+',linestyle='-',color='black')
ax[6].errorbar(times1,S_abu1,yerr=S_er1,fmt='+',linestyle='-',color='cyan')
ax[6].axhline(y=7.27,linestyle=':',color='blue',label='S')
#ax[3].axvline(400,linestyle='--',color='black',label='M6 flare peak')
ax[6].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[6].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[7].plot(time,r_chi,'+',color='blue')
ax[7].plot(tim,r_ch,'+',color='black')
ax[7].plot(tim1,r_ch1,'+',color='cyan')
ax[7].set_ylabel('reduced chi-square')
ax[7].set_xlabel('Time(sec)')
ax[7].tick_params(axis='y',labelcolor='red')


 
plt.savefig("paper/xsm_solexs_2_10.png",dpi=600,bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits




fig,ax=plt.subplots(8,1,figsize=(9,12),gridspec_kw={'height_ratios':(4,2,2,2,2,2,2,1)},sharex=True)



  
ax[0].plot(time,temperatur,'+',linestyle='-',color='blue',label='XSM')
ax[0].plot(time11,temperatur11,'+',linestyle='-',color='black',label='SoLEXS')
ax[0].set_ylabel('Temperature(MK)')
ax[0].tick_params(axis='y')
ax[0].set_title("Energy range 2.2 to 10keV")
ax[0].legend(bbox_to_anchor=(1.15, 1), loc='upper left')
axs2=ax[0].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[1].plot(time,norm,'+',linestyle='-',color='blue')
ax[1].plot(time11,norm11,'+',linestyle='-',color='black')
ax[1].set_ylabel('Emission measure (1e46)')
ax[1].tick_params(axis='y',labelcolor='r')

axs2=ax[1].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')



ax[2].errorbar(timeFe,Fe_abun,yerr=Fe_err,fmt='+',linestyle='-',color='blue')
ax[2].errorbar(timeFe11,Fe_abun11,yerr=Fe_err11,fmt='+',linestyle='-',color='black')
ax[2].axhline(y=8.10,linestyle='--',color='black',label='Fe')
ax[2].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[2].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')


ax[3].errorbar(timeNi,Ni_abun,yerr=Ni_err,fmt='+',linestyle='-',color='blue')
ax[3].errorbar(timeNi11,Ni_abun11,yerr=Ni_err11,fmt='+',linestyle='-',color='black')
ax[3].axhline(y=6.84,linestyle='-.',color='blue',label='Ni')
#ax[1].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[1].set_ylim(5,10)
ax[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[3].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')




ax[4].errorbar(timeCa,Ca_abun,yerr=Ca_err,fmt='+',linestyle='-',color='blue')
ax[4].errorbar(timeCa11,Ca_abun11,yerr=Ca_err11,fmt='+',linestyle='-',color='black')
ax[4].axhline(y=6.93,linestyle='--',color='black',label='Ca')
ax[4].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[4].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')



ax[5].errorbar(timeAr,Ar_abun,yerr=Ar_err,fmt='+',linestyle='-',color='blue')
ax[5].errorbar(timeAr11,Ar_abun11,yerr=Ar_err11,fmt='+',linestyle='-',color='black')
ax[5].axhline(y=6.58,linestyle='-',color='blue', label='Ar')
ax[5].set_ylabel('Abundance')
#ax[2].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[2].set_ylim(5.5,8)
ax[5].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[5].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[6].errorbar(time,S_abun,yerr=S_err,fmt='+',linestyle='-',color='blue')
ax[6].errorbar(time11,S_abun11,yerr=S_err11,fmt='+',linestyle='-',color='black')
ax[6].axhline(y=7.27,linestyle=':',color='blue',label='S')
#ax[3].axvline(400,linestyle='--',color='black',label='M6 flare peak')
ax[6].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[6].twinx()
axs2.plot(tme,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[7].plot(time,r_chi,'+',color='blue')
ax[7].plot(time11,r_chi11,'+',color='black')
ax[7].set_ylabel('reduced chi-square')
ax[7].set_xlabel('Time(sec)')
ax[7].tick_params(axis='y',labelcolor='red')


 
plt.savefig("paper/solexs_fakeit_2_10.png",dpi=600,bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1541/2597757675.py:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1541/2597757675.py:58: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1541/2597757675.py:71: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1541/2597757675.py:86: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')
# /tmp/ipykernel_1541/2597757675.py:97: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs2.legend(loc='lower right')

# %%
model4=Model("chisoth")
model4(1).values=7.2
model4(27).values=6
Plot("model")

energy2 = np.array(xspec.Plot.x(1))

chisoth_model4 = np.array(xspec.Plot.model(1)) 

model4(1).values=7.2
model4(27).values=5
Plot("model")
chisoth_model5 = np.array(xspec.Plot.model(1)) 

model4(1).values=7.2
model4(27).values=4.4
Plot("model")
chisoth_model6 = np.array(xspec.Plot.model(1))

# %%
plt.plot(energy2,chisoth_model4,label="15.8MK")
plt.plot(energy2,chisoth_model5,label="15.8MK")
plt.plot(energy2,chisoth_model6,label="15.8MK")
plt.yscale('log')
plt.xlim(1,9)
#plt.ylim(10e-4,10e6)

plt.legend()
plt.show()

# %%
import xspec
from xspec import *
AllData.clear()
AllModels.clear()

specfile="paper/ch2_xsm_20240912_1_snr.pha"

#arf="ch2_xsm_20240212_1.arf"

spec = xspec.Spectrum(specfile)

xspec.AllModels.systematic = 0.0

Plot.device = '/xw'    
Plot.xAxis = 'keV'

spec.ignore("**-2.2 10.0-**")

# %%
AllModels.clear()

model=Model("chisoth")


# Perform the fit
#Fit.perform()

model(1).values=[7] 


model(18).frozen = False  # Ar Abundance
model(20).frozen = False  #Ca Abundance
model(26).frozen = False  # Fe Abundance
model(28).frozen = False #Ni Abundance
model(27).frozen=False
#model(14).frozen=False
model(16).frozen=False
#model(13).frozen=False

#model(28).link = "26"

Fit.perform()

# Extract the required parameters
temperature1 = model(1).values[0]  # Temperature 
emission_measure1 = model(31).values[0]  #Emission Measure 
Fe_abundance1 = model(26).values[0] 
Ca_abundance1 = model(20).values[0]  
Ar_abundance1 = model(27).sigma 
Ni_abundance1 = model(27).values[0]
#Gain=gain.slope.values[0]
#Offset=gain.offset.values[0]
Mg_abundance1 = model(12).values[0]
Si_abundance1 = model(14).values[0]
S_abundance1 = model(16).values[0]
Al_abundance1 = model(13).values[0]
#Sigma1=model(32).values[0]
#temperature2=model(32).values[0]
#emission_measure2=model(62).values[0]
#Sigma2=model(65).values[0]
chisq = Fit.statistic  # Total chi-square value
dof = Fit.dof          # Degrees of freedom
re_chi1 = chisq / dof  # Reduced chi-square
Plot.background = True
Plot("ldata","delchi")
#Plot('data')
bkg = Plot.backgroundVals()
# Retrieve error arrays
xErrs = Plot.xErr()
yErrs = Plot.yErr()

#xspec.Plot("ldata model")

spectrum = np.array(xspec.Plot.y(1))   
energy = np.array(xspec.Plot.x(1)) 
energy_err=np.array(xspec.Plot.xErr(1))
chisoth_model1 = np.array(xspec.Plot.model(1)) 
spectrum_error = np.array(xspec.Plot.yErr(1))
delchi=np.array(xspec.Plot.y(plotGroup=1, plotWindow=2))
delchiErr=np.array(xspec.Plot.yErr(plotGroup=1, plotWindow=2))

# %%
plt.plot(energy,spectrum)
plt.plot(energy,chisoth_model1)
plt.yscale('log')
plt.show()
