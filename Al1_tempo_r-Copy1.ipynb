# %%
import numpy as np
import os
import datetime
from astropy.io import fits
import xspec
from xspec import *
from xspec import AllModels, AllData, Fit, Plot

AllData.clear()
AllModels.clear()

basepathmod = '/mnt/c/Users/User/Downloads/chspec-main/'
AllModels.lmod('chspec', dirPath=basepathmod)
print("Model package chisoth successfully loaded.")

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
import glob


# Initialize lists to store the results
temperatur = []

norm = []
r_chi=[]

Fe_abun=[]
Ni_abun=[]
S_err=[]
Ca_abun=[]
Ar_abun=[]
S_abun=[]
Fe_err=[]
Ni_err=[]
Ar_err=[]
Ca_err=[]
time=[]
timeFe=[]
timeNi=[]
timeCa=[]
timeAr=[]
timeS=[]
# Load the data file
#file = "spectra/spectra1/Al1_spec"

Plot.device = '/xw'    
Plot.xAxis = 'keV'

#Plot('ld')

# %%
#files1 = sorted(glob.glob("paper/Al1_20240911_trd/" + "*.pi"))
files1="paper/ch2_xsm_20240911_2_trd.pha"
for i in range(1,45):
#for i, file in enumerate(files1):
    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(f"{files1}{{{i}}}")
    
    
    spec.ignore("**-2.1 10.0-**")
    xspec.AllModels.systematic = 0.00
    xspec.AllModels.clear()
    time.append(i*60)
    model1 = xspec.Model("chisoth")
    model1(1).values=[7]
    xspec.Fit.perform()

    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    #model1(14).frozen=False #Si abundance
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abun.append(model1(26).values[0])
       Fe_err.append(model1(26).sigma)
       timeFe.append(i*60)
    if model1(20).sigma<=1:   
       Ca_abun.append(model1(20).values[0])
       Ca_err.append(model1(20).sigma)
       timeCa.append(i*60)
    if model1(18).sigma<=1:
       Ar_abun.append(model1(18).values[0]) 
       Ar_err.append(model1(18).sigma)
       timeAr.append(i*60)
    if model1(28).sigma<=1:
       Ni_abun.append(model1(28).values[0])
       Ni_err.append(model1(28).sigma)
       timeNi.append(i*60)
    if model1(16).sigma<=1:
       S_abun.append(model1(16).values[0])
       S_err.append(model1(16).sigma)
       timeS.append(i*60)
    #Si_abun.append(model1(14).values[0])
    temp=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatur.append(temp/1000000)
    norm.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_chi.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
#files2 = sorted(glob.glob("paper/Al1_20240912_trp/" + "*.pi"))
files2="ch2_xsm_20240912_2_trp.pha"
for i in range(1,99):
#for i, file in enumerate(files2):
    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(f"{files2}{{{i}}}")
    
    
    spec.ignore("**-2.1 10.0-**")
    #xspec.AllModels.systematic = 0.04
    xspec.AllModels.clear()
    
    time.append(2640+(i*30))
    model1 = xspec.Model("chisoth")
    model1(1).values=[7]
    xspec.Fit.perform()

    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    #model1(14).frozen=False #Si abundance
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abun.append(model1(26).values[0])
       Fe_err.append(model1(26).sigma)
       timeFe.append(2640+(i*30))
    if model1(20).sigma<=1:   
       Ca_abun.append(model1(20).values[0])
       Ca_err.append(model1(20).sigma)
       timeCa.append(2640+(i*30))
    if model1(18).sigma<=1:
       Ar_abun.append(model1(18).values[0]) 
       Ar_err.append(model1(18).sigma)
       timeAr.append(2640+(i*30))
    if model1(28).sigma<=1:
       Ni_abun.append(model1(28).values[0])
       Ni_err.append(model1(28).sigma)
       timeNi.append(2640+(i*30))
    if model1(16).sigma<=1:
       S_abun.append(model1(16).values[0])
       S_err.append(model1(16).sigma)
       timeS.append(2640+(i*30))
    #Si_abun.append(model1(14).values[0])
    temp=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatur.append(temp/1000000)
    norm.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_chi.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
#files3 = sorted(glob.glob("paper/Al1_20240912_trd/" + "*.pi"))
files3="paper/ch2_xsm_20240912_2_trd.pha"
for i in range(1,83):
#for i, file in enumerate(files3):
    
    AllData.clear()
    AllModels.clear()
    spec=xspec.Spectrum(f"{files3}{{{i}}}")
    
    
    spec.ignore("**-2.1 10.0-**")
    #xspec.AllModels.systematic = 0.04
    xspec.AllModels.clear()
    
    #time.append(5580+(i*60))
    time.append(6260+(i*60))
    model1 = xspec.Model("chisoth")
    model1(1).values=[7]
    xspec.Fit.perform()

    model1(18).frozen = False  # Ar Abundance
    model1(20).frozen = False  #Ca Abundance
    model1(26).frozen = False  # Fe Abundance
    model1(28).frozen = False #Ni Abundance
    model1(16).frozen=False # S abundance
    #model1(14).frozen=False #Si abundance
    xspec.Fit.perform()

    if model1(26).sigma<=1:
       Fe_abun.append(model1(26).values[0])
       Fe_err.append(model1(26).sigma)
       timeFe.append(6260+(i*60))
    if model1(20).sigma<=1:   
       Ca_abun.append(model1(20).values[0])
       Ca_err.append(model1(20).sigma)
       timeCa.append(6260+(i*60))
    if model1(18).sigma<=1:
       Ar_abun.append(model1(18).values[0]) 
       Ar_err.append(model1(18).sigma)
       timeAr.append(6260+(i*60))
    if model1(28).sigma<=1:
       Ni_abun.append(model1(28).values[0])
       Ni_err.append(model1(28).sigma)
       timeNi.append(6260+(i*60))
    if model1(16).sigma<=1:
       S_abun.append(model1(16).values[0])
       S_err.append(model1(16).sigma)
       timeS.append(6260+(i*60))
    #Si_abun.append(model1(14).values[0])
    temp=10**model1(1).values[0]
    
    # Perform the fit
     #xspec.Fit.perform()
    # Extract the parameters
    temperatur.append(temp/1000000)
    norm.append(model1(31).values[0])
    chisq = Fit.statistic  # Total chi-square value
    dof = Fit.dof          # Degrees of freedom
    reduced_chisq = chisq / dof  # Reduced chi-square
    r_chi.append(reduced_chisq) 
    xspec.Plot("ldata delchi")

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits




fig,ax=plt.subplots(7,1,figsize=(9,12),gridspec_kw={'height_ratios':(4,2,2,2,2,2,1)},sharex=True)




ax[0].plot(time,temperatur,'+',linestyle='-',label='Temperature')
ax[0].set_ylabel('Temperature(MK)')
ax[0].tick_params(axis='y')
ax[0].axvspan(0,2640,color='black',alpha=0.2,label='60sec')
ax[0].axvspan(2640,5580,color='red',alpha=0.2,label='30sec')
ax[0].axvspan(5580,11100,color='blue',alpha=0.2,label='60sec')
ax[0].axvline(3362,linestyle='--',color='blue',alpha=0.2,label='M2 flare peak')
ax[0].legend(bbox_to_anchor=(1.15, 1), loc='upper left')
axs2=ax[0].twinx()
axs2.plot(time,norm,'+',linestyle='-',color='r',label='Emission measure')
axs2.set_ylabel('Emission measure (1e46)')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')



ax[1].errorbar(timeFe,Fe_abun,yerr=Fe_err,fmt='+',linestyle='-',color='black',label='Fe')
ax[1].axhline(y=8.10,linestyle='--',color='black')
ax[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax[2].errorbar(timeNi,Ni_abun,yerr=Ni_err,fmt='+',linestyle='-',label='Ni',color='green')
ax[2].axhline(y=6.84,linestyle='-.',color='green')
#ax[1].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[1].set_ylim(5,10)
ax[2].legend(bbox_to_anchor=(1.05, 1), loc='upper left')



ax[3].errorbar(timeCa,Ca_abun,yerr=Ca_err,fmt='+',linestyle='-',color='r',label='Ca')
ax[3].axhline(y=6.93,linestyle='--',color='r')
ax[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax[4].errorbar(timeAr,Ar_abun,yerr=Ar_err,fmt='+',linestyle='-',color='purple',label='Ar')
ax[4].axhline(y=6.58,linestyle='-',color='purple')
ax[4].set_ylabel('Abundance')
#ax[2].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[2].set_ylim(5.5,8)
ax[4].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

#ax[3].errorbar(time12,Si_abun,yerr=Si_err,fmt='+',linestyle='-',color='black',label='Si')
#ax[3].axhline(y=8.10,linestyle='--',color='black')
ax[5].errorbar(time,S_abun,yerr=S_err,fmt='+',linestyle='-',color='blue',label='S')
ax[5].axhline(y=7.27,linestyle=':',color='blue')
#ax[3].axvline(400,linestyle='--',color='black',label='M6 flare peak')
ax[5].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#ax[3].set_ylim(6,9)

ax[6].plot(time,r_chi,'+',color='red',label='reduced chi-square')
ax[6].set_ylabel('reduced chi-square')
ax[6].set_xlabel('Time(sec)')
ax[6].tick_params(axis='y',labelcolor='red')
ax[6].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

for axs in ax:
    axs.axvspan(0, 2640, color='black', alpha=0.2, label='60sec')
    axs.axvspan(2640, 5580, color='red', alpha=0.2, label='30sec')
    axs.axvspan(5580, 11100, color='blue', alpha=0.2, label='60sec')
    axs.axvline(3362, linestyle='--', color='blue', alpha=0.2, label='M2 flare peak')
plt.savefig("paper/Al1_2_10.png",dpi=600,bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

#Opening fits file
#file=fits.open("/mnt/c/Users/User/Downloads/work/ch2_xsm_20240911_v1/xsm/data/2024/09/11/calibrated/ch2_xsm_20240911_v1_level2.lc")
file=fits.open("/mnt/c/Users/User/Downloads/work/AL1_SOLEXS_20240911_SDD2_L1.lc")
print(file.info())
#extracting data
data=file[1].data

print(file[1].header)
time2 = data['TIME']
counts = data['COUNTS']
#plotting
plt.figure(figsize=(10, 6))
plt.xscale('log')
#plt.axvspan(242867729.83908,242870399.603349) 
plt.plot(time2, counts,'o',label='XSM light curve')
# Out:
# Filename: /mnt/c/Users/User/Downloads/work/AL1_SOLEXS_20240911_SDD2_L1.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      15   ()
#   1  RATE          1 BinTableHDU     39   86400R x 2C   [D, D]
# None
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                   16 / length of dimension 1                          NAXIS2  =                86400 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                    2 / number of table fields                         EXTNAME = 'RATE    '           / Extension name                                 CONTENT = 'LIGHT CURVE'        / File content                                   HDUCLASS= 'OGIP    '           / format conforms to OGIP standard               HDUVERS = '1.1.0   '           / Version of format (OGIP memo CAL/GEN/92-002a)  HDUDOC  = 'OGIP memos CAL/GEN/92-007' / Documents describing the format         HDUVERS1= '1.0.0   '           / Obsolete - included for backwards compatibilityHDUVERS2= '1.1.0   '           / Obsolete - included for backwards compatibilityHDUCLAS1= 'LIGHTCURVE'         / Extension contains spectral data               HDUCLAS2= 'TOTAL   '                                                            HDUCLAS3= 'COUNTS  '                                                            FILTER  = 'SDD2    '           / Filter used                                    TTYPE1  = 'TIME    '                                                            TFORM1  = 'D       '                                                            TTYPE2  = 'COUNTS  '                                                            TFORM2  = 'D       '                                                            CREATOR = 'solexs_pipeline-1.0'                                                 TSTART  =         1725993000.0                                                  TSTOP   =         1726079399.0                                                  TIMEDEL =                    1                                                  TIMZERO =                    0                                                  MJDREFI =                40587                                                  MJDREFF =        0.22916666651                                                  TIMESYS = 'UTC     '                                                            TIMEREF = 'LOCAL   '                                                            TIMEUNIT= 's       '                                                            DATE-OBS= '2024-09-11 00:00:00'                                                 DATE-END= '2024-09-11 23:59:59'                                                 TELESCOP= 'AL1     '                                                            INSTRUME= 'SoLEXS  '                                                            NUMBAND = '4       '                                                            DATASUM = '3284931667'         / data unit checksum updated 2024-12-31T14:52:31 END

# %%
time2[74849]
# Out:
# 242870398.83808005

# %%
Time=[]
Time.append(time2[83729:86399])
#Time.append(time2[72580:74849])

# %%
Counts=[]
Counts.append(counts[83729:86399])
#Counts.append(counts[72580:74849])

# %%
file=fits.open("/mnt/c/Users/User/Downloads/work/AL1_SOLEXS_20240912_SDD2_L1.lc")
#file=fits.open("/mnt/c/Users/User/Downloads/work/ch2_xsm_20240912_v1/xsm/data/2024/09/12/calibrated/ch2_xsm_20240912_v1_level2.lc")
print(file.info())
#extracting data
data=file[1].data

print(file[1].header)
time1 = data['TIME']
counts1 = data['COUNTS']
#plotting
plt.figure(figsize=(10, 6))
plt.xscale('log')
#plt.axvspan(242867729.83908,242870399.603349) 
plt.plot(time1, counts1,'o',label='XSM light curve')
# Out:
# Filename: /mnt/c/Users/User/Downloads/work/AL1_SOLEXS_20240912_SDD2_L1.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      15   ()
#   1  RATE          1 BinTableHDU     39   86400R x 2C   [D, D]
# None
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                   16 / length of dimension 1                          NAXIS2  =                86400 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                    2 / number of table fields                         EXTNAME = 'RATE    '           / Extension name                                 CONTENT = 'LIGHT CURVE'        / File content                                   HDUCLASS= 'OGIP    '           / format conforms to OGIP standard               HDUVERS = '1.1.0   '           / Version of format (OGIP memo CAL/GEN/92-002a)  HDUDOC  = 'OGIP memos CAL/GEN/92-007' / Documents describing the format         HDUVERS1= '1.0.0   '           / Obsolete - included for backwards compatibilityHDUVERS2= '1.1.0   '           / Obsolete - included for backwards compatibilityHDUCLAS1= 'LIGHTCURVE'         / Extension contains spectral data               HDUCLAS2= 'TOTAL   '                                                            HDUCLAS3= 'COUNTS  '                                                            FILTER  = 'SDD2    '           / Filter used                                    TTYPE1  = 'TIME    '                                                            TFORM1  = 'D       '                                                            TTYPE2  = 'COUNTS  '                                                            TFORM2  = 'D       '                                                            CREATOR = 'solexs_pipeline-1.0'                                                 TSTART  =         1726079400.0                                                  TSTOP   =         1726165799.0                                                  TIMEDEL =                    1                                                  TIMZERO =                    0                                                  MJDREFI =                40587                                                  MJDREFF =        0.22916666651                                                  TIMESYS = 'UTC     '                                                            TIMEREF = 'LOCAL   '                                                            TIMEUNIT= 's       '                                                            DATE-OBS= '2024-09-12 00:00:00'                                                 DATE-END= '2024-09-12 23:59:59'                                                 TELESCOP= 'AL1     '                                                            INSTRUME= 'SoLEXS  '                                                            NUMBAND = '4       '                                                            DATASUM = '3289278185'         / data unit checksum updated 2024-12-31T14:54:54 END

# %%
time3=time1[0:8520]
#time3=time1[0:7855]
Time.append(np.array(time3))
Counts.append(counts1[0:8520])
#Counts.append(counts1[0:7855])

# %%
cnts = np.concatenate(Counts)
tme=np.concatenate(Time)

# %%
tme1=tme-tme[0]

# %%
import datetime


def timestamp2datetime(timestamp_arr):
    datetime_arr = []
    for ta in timestamp_arr:
        datetime_arr.append(datetime.datetime.fromtimestamp(ta))
    return datetime_arr
converted_datetimes = timestamp2datetime(tme)

# %%
converted_datetimes[2400]
# Out:
# datetime.datetime(2024, 9, 11, 23, 55, 29)

# %%
plt.plot(converted_datetimes,cnts)
plt.axvline(converted_datetimes[2400],linestyle='-',label='flare peak observed in 193A')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits




fig,ax=plt.subplots(8,1,figsize=(9,12),gridspec_kw={'height_ratios':(4,2,2,2,2,2,2,1)},sharex=True)




ax[0].plot(time,temperatur,'+',linestyle='-',label='Temperature')
ax[0].set_ylabel('Temperature(MK)')
ax[0].tick_params(axis='y')
ax[0].axvspan(0,2640,color='black',alpha=0.2,label='60sec')
ax[0].axvspan(2640,6260,color='red',alpha=0.2,label='30sec')
ax[0].axvspan(6260,11100,color='blue',alpha=0.2,label='60sec')
ax[0].legend(bbox_to_anchor=(1.15, 1), loc='upper left')
axs2=ax[0].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[1].plot(time,norm,'+',linestyle='-',color='r',label='Emission measure')
ax[1].set_ylabel('Emission measure (1e46)')
ax[1].tick_params(axis='y',labelcolor='r')
ax[1].legend(loc='lower right')
axs2=ax[1].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2)
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')



ax[2].errorbar(timeFe,Fe_abun,yerr=Fe_err,fmt='+',linestyle='-',color='black',label='Fe')
ax[2].axhline(y=8.10,linestyle='--',color='black')
ax[2].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[2].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')


ax[3].errorbar(timeNi,Ni_abun,yerr=Ni_err,fmt='+',linestyle='-',label='Ni',color='green')
ax[3].axhline(y=6.84,linestyle='-.',color='green')
#ax[1].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[1].set_ylim(5,10)
ax[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[3].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')




ax[4].errorbar(timeCa,Ca_abun,yerr=Ca_err,fmt='+',linestyle='-',color='r',label='Ca')
ax[4].axhline(y=6.93,linestyle='--',color='r')
ax[4].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[4].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')


ax[5].errorbar(timeAr,Ar_abun,yerr=Ar_err,fmt='+',linestyle='-',color='purple',label='Ar')
ax[5].axhline(y=6.58,linestyle='-',color='purple')
ax[5].set_ylabel('Abundance')
#ax[2].axvline(400,linestyle='--',color='black',label='M6 flare peak')
#ax[2].set_ylim(5.5,8)
ax[5].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[5].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[6].errorbar(time,S_abun,yerr=S_err,fmt='+',linestyle='-',color='blue',label='S')
ax[6].axhline(y=7.27,linestyle=':',color='blue')
#ax[3].axvline(400,linestyle='--',color='black',label='M6 flare peak')
ax[6].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs2=ax[6].twinx()
axs2.plot(tme1,cnts,color='b',alpha=0.2,label='M2 Flare')
axs2.set_ylabel('Counts')
axs2.tick_params(axis='y',labelcolor='r')
axs2.legend(loc='lower right')

ax[7].plot(time,r_chi,'+',color='red',label='reduced chi-square')
ax[7].set_ylabel('reduced chi-square')
ax[7].set_xlabel('Time(sec)')
ax[7].tick_params(axis='y',labelcolor='red')
ax[7].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

for axs in ax:
    axs.axvspan(0, 2640, color='black', alpha=0.2, label='60sec')
    axs.axvspan(2640, 6260, color='red', alpha=0.2, label='30sec')
    axs.axvspan(6260, 11100, color='blue', alpha=0.2, label='60sec')
   
plt.savefig("paper/xsm_2_10.png",dpi=600,bbox_inches='tight')
plt.show()
